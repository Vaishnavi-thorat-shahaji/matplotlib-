# %%
! pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.3 is available.
# You should consider upgrading via the 'C:\Users\vaish\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib

# %%
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_api',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_listed',
#  '_color_data',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_init_tests',
#  '_label_from_arg',
#  '_log',
#  '_logged_cached',
#  '_open_file_or_url',
#  '_parse_to_version_info',
#  '_path',
#  '_preprocess_data',
#  '_rc_params_in_file',
#  '_replacer',
#  '_version',
# ...

# %%
print(matplotlib.__version__)
# Out:
# 3.7.3

# %%
import matplotlib.pyplot as plt
# %matplotlib.inline
import numpy as np
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
import numpy as np
xpoint = np.array([0,6])
ypoint = np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([0,4])
ypoint = np.array([0,300])
plt.plot(xpoint,ypoint)

# %%
xpoint = np.array([1,3])
ypoint = np.array([4,10])
plt.plot(xpoint, ypoint ,'go--')
plt.show()

# %%
xpoint = np.array([0,10])
ypoint = np.array([1,5])
plt.plot(xpoint,ypoint, 'o')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoint = np.array([0,5])
ypoint = np.array([0,10])
plt.plot(xpoint,ypoint)

# %%
x = np.array([1,10,100])
y = np.array([2,20,200])
plt.plot(x,y,color = 'yellow')

# %%
xpoint = np.array([1,2,4,6])
ypoint = np.array([1,3,5,7])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([1,4,7,9])
ypoint = np.array([3,6,5,8])
plt.plot(xpoint,ypoint,'*')
plt.show()

# %%
ypoint = np.array([1,3,5,7])
plt.plot(ypoint)
plt.show()

# %%
xpoint = np.array([1,2,3])
ypoint = np.array([4,5,6])
plt.plot(xpoint,ypoint,'.')
plt.show()
plt.plot(xpoint, ypoint,'*')
plt.show()
plt.plot(xpoint, ypoint,'P')
plt.show()
plt.plot(xpoint, ypoint,'H')
plt.show()
plt.plot(xpoint,ypoint)
plt.show()

# %%
plt.plot(xpoint,ypoint,color ='red')
plt.show()

# %%
plt.plot(xpoint, ypoint,color ='green')
plt.show()

# %%
plt.plot(xpoint, ypoint,color = 'black')
plt.show()

# %%
ypoint = np.array([1,3,5,7])
plt.plot(ypoint, marker = 'd')
plt.show()

# %%
ypoint = np.array([3,5,8,10])
plt.plot(ypoint,'o:r')
plt.show()

# %%
ypoint = np.array([2,5,8,10])
plt.plot(ypoint , '*:b')
plt.show()

# %%
ypoint = np.array([2,4,6,8])
plt.plot(ypoint , marker ='o',ms = 15)
plt.show()

# %%
ypoint = np.array([3,5,7,9])
plt.plot(ypoint, marker ='o',ms =20, mec ='y')

# %%
ypoint = np.array([11,33,55,77])
plt.plot(ypoint, marker = 'o',ms = 10, mec='r',mfc='y')
plt.show()

# %%
xpoint = np.array([100,200,300])
ypoint = np.array([500,600,700])
plt.plot(xpoint, ypoint,'*')

# %%
ypoint = np.array([33,55,77,99])
plt.plot(ypoint)
plt.show()

# %%
ypoint = np.array([33,55,77,99])
plt.plot(ypoint,'Pr')
plt.show()

# %%
ypoint = np.array([11,22,33,44,55,66])
plt.plot(ypoint, '^:y')
plt.show()

# %%
xpoint = np.array([100,200,300])
ypoint = np.array([500,600,700])
plt.plot(xpoint, ypoint,'^:g')

# %%
ypoint = np.array([1,100])
plt.plot(ypoint,'2-.k')

# %%
ypoint = np.array([22,44])
plt.plot(ypoint, '_-.m')

# %%
ypoint = np.array([22,44,66])
plt.plot(ypoint, 'Hk',ms =5)

# %%
ypoint = np.array([1,2,3,4])
plt.plot(ypoint,'o',ms=7,mec ='b',mfc ='m')

# %%
ypoint = np.array([2.2,4.4])
plt.plot(ypoint, 'X', ms =10, mec = 'k',mfc ='w')

# %% [markdown]
# ### linestyle

# %%
ypoint = np.array([0,0.5,1])
plt.plot(ypoint, linestyle = ':',color= 'k')

# %%
ypoint = np.array([3,5,8,10])
plt.plot(ypoint, linestyle ='-',color = 'm')

# %%
ypoint = np.array([2,5])
plt.plot(ypoint, color = 'c')

# %% [markdown]
# # linewidth

# %%
ypoint = np.array([1,2,3])
xpoint = np.array([4,5,6])
plt.plot(xpoint,ypoint,linewidth ='2.5')
plt.show()

# %%
ypoint = np.array([22,44,66])
plt.plot(ypoint, linewidth ='5.5')
plt.show()

# %%
y1 = np.array([11,33,55])
y2 = np.array([22,44,66])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y = np.array([3,8,1,10])
x = np.array([6,2,7,11])
plt.plot(y, linestyle = 'dotted')
plt.plot(x, linewidth = '5')
plt.show()

# %%
y = np.array([3,8,1,10])
x = np.array([6,2,7,11])
plt.plot(y, linestyle = '--')
plt.plot(x, linewidth = '3')
plt.show()

# %%
x1 = np.array([3,8,7,10])
y1 = np.array([33,55,99,88])
x2 = np.array([3,8,7,10])
y2 = np.array([11,44,66,77])
plt.plot(x1,y1,x2,y2,linewidth = '5',linestyle = 'dashed')
plt.show()

# %% [markdown]
# ### label to plot

# %%
x = np.array([80,85,3,2])
y = np.array([240,250,340,100])
plt.plot(x,y)
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.show()

# %%
x = np.array([11,12,13,14])
y = np.array([15,16,17,18])
plt.plot(x,y,'X',ms = 10, mfc = 'g',mec ='r')
plt.title('plot chart',loc ='center',fontsize='20')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.show()

# %%
x = np.array([10,20,30,40])
y = np.array([50,60,70,80])
plt.plot(x,y,'o',ms = 10, mec = 'b',mfc='r')
plt.title('plot chart', loc = 'right')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.grid()
plt.show()

# %%
x = np.array([10,20,30,40])
y = np.array([100,200,300,400])
plt.plot(x,y)
plt.grid(axis = 'x')
#plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,22,3])
y = np.array([4,55,6])
plt.plot(x,y)
plt.show()

# %%
x = np.array([10,20,30,40])
y = np.array([2.3,4.5,6.5,7.8])
plt.plot(x,y,'+y')

# %%
y = np.array([22,33,44])
plt.plot(y,'D',ms =5,mec ='y',mfc ='k')
plt.show()

# %%
y = np.array([0,0.10])
plt.plot(y,'1y')

# %%
y = np.array([111,222,333,444,555])
plt.plot(y,'+:m',ms = 10)
plt.show()

# %%
y = np.array([11,22,33,44])
plt.plot(y,':.c')

# %%
y = np.array([1,3,7,4])
plt.plot(y,linestyle = 'dashdot')
plt.show()

# %%
y = np.array([1,3,7,4])
plt.plot(y,linestyle = 'dashed')
plt.show()

# %%
y = np.array([11,22,33,44])
plt.plot(y,color = 'r')
plt.show()

# %%
y = np.array([11,22,33,44,55])
plt.plot(y,'+y',linewidth ='5')
plt.show()

# %%
y1 = np.array([11,22,33])
y2 = np.array([55,77,99])
plt.plot(y1,'>')
plt.plot(y2,'<')

# %%
x = np.array([100,2,300])
y = np.array([400,5,600])
plt.plot(x, linestyle = 'dashed')
plt.plot(y, linewidth = '4')
plt.show()

# %%
x1 = np.array([0,1,2,3])
y1 = np.array([11,22,33,44])
plt.plot(x1,y1)

# %%
y = np.array([11,22,33,44])
plt.plot(y)
plt.title('plot chart',loc ='left')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid()

# %%
y = np.array([0,1,2,3,4])
plt.subplot(1,2,1)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y = np.array([0,1,2,3,4])
#       2 plt.subplot(1,2,1)
#       3 plt.plot()
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0,3])
y = np.array([1,3])
plt.plot(x,y)
plt.show()

# %%
x = np.array([11,22,33])
y = np.array([0,256,10])
plt.plot(x,y,'vk')
plt.show()

# %%
y = np.array([100,10,1,0])
plt.plot(y)
plt.show()

# %%
y = np.array([1000,100,10,1,0])
plt.plot(y,'2')
plt.show()

# %%
y = np.array([1.1,2.2,3.3,4.4,100.0])
plt.plot(y,'X''k')
plt.show()

# %%
y = np.array([99,98,80,10,2,1])
plt.plot(y,'o',ms = 10,mec ='k',mfc='m')
plt.show()

# %%
y = np.array([10,9,8,7,6,5,4,3])
plt.plot(y,linestyle = 'dashdot',color = 'm',linewidth = 5)

# %%
x1 = np.array([1,2,3,4,5])
y1 = np.array([10,20,30,40,50])
x2 = np.array([11,34,56,78,89])
y2 = np.array([100,99,88,77,66])
plt.plot(x1,y1,x2,y2,linewidth = '5',linestyle = 'dashdot',color ='m')
plt.show()

# %%
y = np.array([1000,100,10,1,0])
plt.plot(y,'*g',ms =10)
plt.title('angle chart',loc = 'left')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.grid()
plt.grid(axis = 'x')

# %%
plt.grid(axis = 'y')

# %%
x = np.array([100,10,1])
y = np.array([3,6,7])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.show()
x1 = np.array([0,10,100,1000])
y1 = np.array([4,6,7,8])
plt.subplot(2,2,1)
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.show()
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.show()

# %%
x = np.array([10,1,20,4])
y = np.array([20,30,40,10])
plt.subplot(2,2,1)
plt.plot(x,y,'o')
plt.title('sales')
plt.show()
x = np.array([1000,100,10,1])
y = np.array([30,0,1,5])
plt.subplot(2,2,1)
plt.plot(x,y,)
plt.title('tax')
plt.show()
plt.subtitle('my shop')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 13
#      11 plt.title('tax')
#      12 plt.show()
# ---> 13 plt.subtitle('my shop')
#      14 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'

# %%
x = np.array([10,20,30,40])
y = np.array([0,2,3,4])
plt.subplot(1,2,2)
plt.plot(x,y)


plt.title('my shop')
plt.show()

# %% [markdown]
# ### scatter plot

# %%
x = np.array([10,20,30])
y = np.array([0,2,3])
plt.scatter(x,y,color = 'y')
plt.show()

# %%
x = np.array([5,6,7,8,3,4,5,6,11,22,44,55,88,77])
y = np.array([4,5,6,10,22,33,43,5,46,67,5,411,22,10])
plt.scatter(x,y,color = 'hotpink')
plt.show()

# %%
x = np.array([5,6,7,8,3,4,5,6,11,22,44,55,88,77,100,22,33,45,6])
y = np.array([4,5,6,10,22,33,43,5,46,67,5,411,22,10,90,60,54,33,1])
colors = np.array([1000,90,80,70,60,50,40,30,22,44,4,10,1,0,11,22,33,44,66])
plt.scatter(x,y,c = colors ,cmap = 'viridis')
plt.show()

# %%
x = np.array([5,6,7,8,3,4,5,6,11,22,44,55,88,77,100,22,33,45,6])
y = np.array([4,5,6,10,22,33,43,5,46,67,5,411,22,10,90,60,54,33,1])
colors = np.array([1000,90,80,70,60,50,40,30,22,44,4,10,1,0,11,22,33,44,66])
plt.scatter(x,y,c = colors ,cmap = 'viridis')
plt.colorbar()
plt.show()

# %%
x = np.array([5,6,7,8,3,4,5,6,11,22,44,55,88,77,100,22,33,45,6])
y = np.array([4,5,6,10,22,33,43,5,46,67,5,411,22,10,90,60,54,33,1])
sizes = np.array([1000,90,80,70,60,50,40,30,22,44,4,10,1,0,11,22,33,44,66])
plt.scatter(x,y,s=sizes)
plt.show()

# %%
x = np.array([5,6,7,8,3,4,5,6,11,22,44,55,88,77,100,22,33,45,6])
y = np.array([4,5,6,10,22,33,43,5,46,67,5,411,22,10,90,60,54,33,1])
sizes = np.array([1000,90,80,70,60,50,40,30,22,44,4,10,1,0,11,22,33,44,66])
plt.scatter(x,y,s = sizes , alpha = 0.5 )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100,size=(100))
sizes=5*np.random.randint(100,size=(100))
plt.scatter(x,y,c =colors, s = sizes, alpha =0.7, cmap='viridis')
plt.colorbar()
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100,size=(100))
sizes=5*np.random.randint(100,size=(100))
plt.scatter(x,y,c =colors, s = sizes, alpha =0.7, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# ### bar plot

# %%
x = np.array(['A','B','C','D'])
y = np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
x = ['apple','kiwi']
y = [200,400]
plt.bar(x,y)
plt.show()

# %% [markdown]
# # barh plot

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.barh(x,y)
plt.show()

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.barh(x,y,color = 'm')
plt.show()

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.bar(x,y,width = 0.1)
plt.show()

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.bar(x,y,width = 0.8, color = 'c')
plt.show()

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.barh(x,y, height = 0.8)
plt.show()

# %%
x = np.array(['a','b','c','d'])
y = np.array([3,2,5,10])
plt.barh(x,y,height = 0.8,color = 'm')
plt.show()

# %% [markdown]
# # histogram

# %%
x = np.random.normal(150,10,250)
plt.hist(x)
plt.show()

# %%
y = np.random.normal(100,5,230)
plt.hist(y)
plt.show()

# %% [markdown]
# # pie charts

# %%
x = np.array([10,20,33,22])
plt.pie(x)
plt.show()

# %%
### labels and explode wedge

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.1,0,0,0]
plt.pie(x,labels = mylabels, explode = myexplode)
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.1,0.2,0.3,0.1]
plt.pie(x,labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ### shadow

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.1,0,0,0]
plt.pie(x,labels = mylabels, explode = myexplode,shadow =True)
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.1,0.2,0,0]
plt.pie(x,labels = mylabels, explode = myexplode,shadow = True)
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
mycolors = ['black','m','c','y']
myexplode = [0.1,0,0,0.2]
plt.pie(x,labels = mylabels, colors = mycolors, explode = myexplode,shadow =True)
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
mycolors = ['black','m','c','y']
myexplode = [0.1,0,0,0.2]
plt.pie(x,labels = mylabels, colors = mycolors, explode = myexplode,shadow =True)
plt.legend()
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
mycolors = ['black','m','c','y']
myexplode = [0.1,0,0,0.2]
plt.pie(x,labels = mylabels, colors = mycolors, explode = myexplode,shadow =True)
plt.legend(title = 'four alphabets:')
plt.show()

# %%
x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
mycolors = ['black','m','c','y']
myexplode = [0.1,0,0,0.2]
plt.pie(x,labels = mylabels, colors = mycolors, explode = myexplode,shadow =True)
plt.legend(title = 'four items:',loc=2)
plt.show()

# %%
x = np.array([10,1,20,4])
y = np.array([20,30,40,10])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title('sales')
plt.show()
x = np.array([1000,100,10,1])
y = np.array([30,0,1,5])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title('tax')

plt.suptitle('my shop')
plt.show()
